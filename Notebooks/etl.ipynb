# %%
import pandas as pd
import ast

# %% [markdown]
# ## DATASET 'Movies'

# %%
df_movies = pd.read_csv(r'C:\Users\GASTON\Desktop\PI1\movies_dataset.csv', low_memory=False)
#Como el archivo CSV es muy grande,con low_memory = False se permite a Pandas leerlo en bloques más pequeños 
# para mejorar el rendimiento

# %%
df_movies.head(3) #Observamos las columnas del dataset
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 2  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 2   1995-12-22          0.0   101.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 0          7.7     5415.0
# 1          6.9     2413.0
# 2          6.5       92.0
#
# [3 rows x 24 columns]

# %% [markdown]
# ## Desanidar columnas

# %%
#Se crea una función para normalizar las columnas anidadas con json normalize
def desanidarColumnas(df, columns):
    '''Esta función espera dos argumentos: el DataFrame a modificar, y una lista de columnas del DataFrame. 
    La función itera sobre esas columnas, convirtiéndolas en cadenas de texto utilizando literal_eval.
    Si la columna es nula, devuelve una lista vacía. 
    Expande las columna, y normaliza con json_normalize.
    Luego elimina la columna expandida. Retorna el DataFrame modificado.
    Requiere importar pandas y ast para funcionar.'''
    for column in columns:
        df[column] = df[column].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])
        # Expandir la columna en filas
        df = df.explode(column)
        # Normalizar la columna expandida
        col_df = pd.json_normalize(df[column])
        # Renombrar las columnas normalizadas para evitar superposiciones
        col_df = col_df.add_prefix(f'{column}')
        # Concatenar las columnas normalizadas con el DataFrame original
        df = df.drop(columns=[column]).reset_index(drop=True).join(col_df)
    return df

# %%
columnas = ['belongs_to_collection', 'production_companies', 'genres', 'production_countries', 'spoken_languages']
#Estas son las columnas anidadas

# %%
df_movies = desanidarColumnas(df_movies, columnas)

# %%
df_movies.head(2)
# Out:
#    adult    budget                              homepage   id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story  862  tt0114709
# 1  False  30000000  http://toystory.disney.com/toy-story  862  tt0114709
#
#   original_language original_title  \
# 0                en      Toy Story
# 1                en      Toy Story
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  Led by Woody, Andy's toys live happily in his ...  21.946943
#
#                         poster_path  ... vote_average  vote_count  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...          7.7      5415.0
# 1  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...          7.7      5415.0
#
#    production_companiesname production_companiesid genresid genresname  \
# 0   Pixar Animation Studios                    3.0     16.0  Animation
# 1   Pixar Animation Studios                    3.0     35.0     Comedy
#
#   production_countriesiso_3166_1  production_countriesname  \
# 0                             US  United States of America
# 1                             US  United States of America
#
#    spoken_languagesiso_639_1 spoken_languagesname
# 0                         en              English
# 1                         en              English
#
# [2 rows x 27 columns]

# %%
#Se corrige la aplicación de ciertos cambios, utilizando strip para eliminar espacios en blanco en las columnas del DF.
def limpiezaColumnas(df):
    for col in df.select_dtypes(include=['object']):
        df[col] = df[col].apply(lambda x: x.strip() if isinstance(x, str) else x)
    return df

# %%
df_movies=limpiezaColumnas(df_movies)

# %% [markdown]
# ## Tratamiento de Nulos
# Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0.

# %%
df_movies['revenue']= df_movies['revenue'].fillna(0) #Reemplazo los valores nulos con 0
df_movies['budget'] = df_movies['budget'].fillna(0) #Reemplazo los nulos con 0

# %% [markdown]
# Eliminar valores nulos del campo 'release_date'

# %%
df_movies.dropna(subset='release_date', inplace=True) #Se eliminan las filas con valores nulos en la columna 'release_date'.

# %% [markdown]
# De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde <br>
# extraerán el año de la fecha de estreno.

# %%
print(type(df_movies['release_date'][1])) #Verificamos el formato de la columna con un registro de la misma
#En este caso, es un str.
# Out:
# <class 'str'>

# %%
df_movies['release_date'] = pd.to_datetime(df_movies['release_date'], format='%Y-%m-%d', errors='coerce') 
#Como hay valores que no son fechas, para manejarlos se usa el parámetro errors='coerce', para convertirlos en Nat (not a time). 
# En este mismo paso asignamos el formato de fecha.

# %%
print("No son fechas:")
verif_fecha = df_movies[df_movies['release_date'].isna()] 
#En este paso identificamos si son elementos considerables. Se trata de 3 filas. Se pueden manejar individualmente,
#pero al tratarse de pocos registros en los que la mayoría de los valores son nulos, se decide eliminarlos.
verif_fecha
# Out:
# No son fechas:
#                                                     adult  \
# 353603                                 - Written by Ørnås
# 353604                                 - Written by Ørnås
# 353605                                 - Written by Ørnås
# 471154  Rune Balot goes to a casino connected to the O...
# 471155  Rune Balot goes to a casino connected to the O...
# 471156  Rune Balot goes to a casino connected to the O...
# 471157  Rune Balot goes to a casino connected to the O...
# 471158  Rune Balot goes to a casino connected to the O...
# 516362  Avalanche Sharks tells the story of a bikini c...
# 516363  Avalanche Sharks tells the story of a bikini c...
# 516364  Avalanche Sharks tells the story of a bikini c...
# 516365  Avalanche Sharks tells the story of a bikini c...
#
#                                   budget  \
# 353603  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 353604  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 353605  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 471154  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 471155  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 471156  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 471157  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 471158  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 516362  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 516363  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 516364  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 516365  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                  homepage          id imdb_id  \
# 353603  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 353604  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 353605  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 471154  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 471155  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 471156  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 471157  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 471158  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 516362           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
# 516363           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
# 516364           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
# 516365           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#        original_language                            original_title  overview  \
# 353603             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 353604             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 353605             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 471154              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 471155              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 471156              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 471157              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 471158              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 516362              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 516363              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 516364              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 516365              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                    popularity                          poster_path  ...  \
# 353603                    NaN                         Midnight Man  ...
# 353604                    NaN                         Midnight Man  ...
# 353605                    NaN                         Midnight Man  ...
# 471154                    NaN  Mardock Scramble: The Third Exhaust  ...
# 471155                    NaN  Mardock Scramble: The Third Exhaust  ...
# 471156                    NaN  Mardock Scramble: The Third Exhaust  ...
# 471157                    NaN  Mardock Scramble: The Third Exhaust  ...
# 471158                    NaN  Mardock Scramble: The Third Exhaust  ...
# 516362  Beware Of Frost Bites                     Avalanche Sharks  ...
# 516363  Beware Of Frost Bites                     Avalanche Sharks  ...
# 516364  Beware Of Frost Bites                     Avalanche Sharks  ...
# 516365  Beware Of Frost Bites                     Avalanche Sharks  ...
#
#        vote_average  vote_count  production_companiesname  \
# 353603          NaN         NaN                       NaN
# 353604          NaN         NaN                       NaN
# 353605          NaN         NaN                       NaN
# 471154          NaN         NaN                       NaN
# 471155          NaN         NaN                       NaN
# 471156          NaN         NaN                       NaN
# 471157          NaN         NaN                       NaN
# 471158          NaN         NaN                       NaN
# 516362          NaN         NaN                       NaN
# 516363          NaN         NaN                       NaN
# 516364          NaN         NaN                       NaN
# 516365          NaN         NaN                       NaN
#
#        production_companiesid genresid                             genresname  \
# 353603                    NaN  11176.0                   Carousel Productions
# 353604                    NaN  11602.0              Vision View Entertainment
# 353605                    NaN  29812.0       Telescene Film Group Productions
# 471154                    NaN   2883.0                                Aniplex
# 471155                    NaN   7759.0                                GoHands
# 471156                    NaN   7760.0                              BROSTA TV
# 471157                    NaN   7761.0  Mardock Scramble Production Committee
# 471158                    NaN  33751.0                       Sentai Filmworks
# 516362                    NaN  17161.0                          Odyssey Media
# 516363                    NaN  18012.0                     Pulser Productions
# 516364                    NaN  18013.0                            Rogue State
# 516365                    NaN  23822.0                             The Cartel
#
#        production_countriesiso_3166_1  production_countriesname  \
# 353603                            NaN                       NaN
# 353604                            NaN                       NaN
# 353605                            NaN                       NaN
# 471154                            NaN                       NaN
# 471155                            NaN                       NaN
# 471156                            NaN                       NaN
# 471157                            NaN                       NaN
# 471158                            NaN                       NaN
# 516362                            NaN                       NaN
# 516363                            NaN                       NaN
# 516364                            NaN                       NaN
# 516365                            NaN                       NaN
#
#         spoken_languagesiso_639_1 spoken_languagesname
# 353603                        NaN                  NaN
# 353604                        NaN                  NaN
# 353605                        NaN                  NaN
# 471154                        NaN                  NaN
# 471155                        NaN                  NaN
# 471156                        NaN                  NaN
# 471157                        NaN                  NaN
# 471158                        NaN                  NaN
# 516362                        NaN                  NaN
# 516363                        NaN                  NaN
# 516364                        NaN                  NaN
# 516365                        NaN                  NaN
#
# [12 rows x 27 columns]

# %%
df_movies = df_movies.dropna(subset=['release_date']) #Usamos dropna() para eliminar filas con valores nulos en release_date

# %%
# Convertir la columna 'release_date' a tipo datetime, manejando los errores
df_movies['release_date'] = pd.to_datetime(df_movies['release_date'], format='%Y-%m-%d', errors='coerce')

# %%
df_movies['release_year'] = df_movies['release_date'].dt.year #Aquí creamos la columna "release_year". 
#A la misma la completamos extrayendo el año de la columna 'release_date'

# %%
df_movies.reset_index(drop=True, inplace=True) # Se reinician los índices

# %% [markdown]
# ## Se agregan métricas (ROI)

# %% [markdown]
# Se crea la columna RETURN, la cual contendrá el resultado de dividir revenue / budget.

# %%
df_movies['return'] = 0.0

# %%
df_movies['budget'] = pd.to_numeric(df_movies['budget'], errors='coerce')
df_movies['revenue'] = pd.to_numeric(df_movies['revenue'], errors='coerce')
#Es necesario convertir los valores a un tipo numérico (int o float) para que los datos tengan coherencia.
# errors=coerce convertirá las que tengan errores en NaN

# %%
df_movies.loc[(df_movies['budget'] > 0) & (df_movies['revenue'] > 0), 'return'] = df_movies['revenue'] / df_movies['budget']
#Se verifica que el valor de 'budget' y/o 'revenue' no sean 0. 
# Si lo son, la columna return conserva el valor '0' que le asignamos al crearla.
#Se utiliza .loc para asignar directamente a través de una selección condicional

# %%
df_movies['return'].isnull().sum() #Analizamos si hay valores nulos
# Out:
# 0

# %% [markdown]
# ## Eliminación de Columnas innecesarias

# %%
df_movies.columns
# Out:
# Index(['adult', 'budget', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'production_companiesname',
#        'production_companiesid', 'genresid', 'genresname',
#        'production_countriesiso_3166_1', 'production_countriesname',
#        'spoken_languagesiso_639_1', 'spoken_languagesname', 'release_year',
#        'return'],
#       dtype='object')

# %%
#En este paso se eliminan las columnas que no se utilizarán
df_movies.drop(columns=['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage'], inplace=True)

# %%
#Observamos las nuevas columnas disponibles
df_movies.columns
# Out:
# Index(['budget', 'id', 'original_language', 'overview', 'popularity',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'production_companiesname',
#        'production_companiesid', 'genresid', 'genresname',
#        'production_countriesiso_3166_1', 'production_countriesname',
#        'spoken_languagesiso_639_1', 'spoken_languagesname', 'release_year',
#        'return'],
#       dtype='object')

# %% [markdown]
# ## Tratamiento de Datos nulos, duplicados y otros valores

# %% [markdown]
# Una vez realizadas las primeras transformaciones, es preciso verificar: <br>
# Filas duplicadas <br>
# Las columnas de texto son de tipo string <br>
# Unificar filas de acuerdo a su id

# %%
duplicadas = df_movies.duplicated().sum()
print(duplicadas)
# Out:
# 163788

# %%
df_movies = df_movies.drop_duplicates() #Se eliminan las filas duplicadas

# %%
duplicadas = df_movies.duplicated().sum()
duplicadas #Verificamos nuevamente
# Out:
# 0

# %%
df_movies.loc[:,'spoken_languagesname'] = df_movies['spoken_languagesname'].astype(str)
df_movies.loc[:,'genresname'] = df_movies['genresname'].astype(str)

# %%
# Agrupar por 'id' y agregar los idiomas y géneros
lang_genres = df_movies.groupby('id').agg({
    'spoken_languagesname': lambda x: ', '.join(set(x)), 
    'genresname': lambda x: ', '.join(set(x)) #Para cada columna, esta función lambda toma grupos de datos y los convierte en sets (elimina duplicados), y luego forma una cadena separadas por comas.
}).reset_index()


otras_col = ['title','budget', 'revenue', 'overview','release_date', 'vote_average', 'vote_count','popularity','runtime', 'status', 'tagline', 'production_companiesname', 'production_countriesname', 'release_year', 'return']
# Se guardan en esta variable las columnas con las que agruparé lang_gentes. Estas son columnas que no necesitan ser 
# agrupadas o agregadas, ya que tienen un solo valor por cada película. Si agrego la lista directamente en el groupby
# me arrojará error. Para solucionar esta cuestión, se utiliza la variable que guarda una lista de columnas.

col_valor_unico = df_movies.groupby('id')[otras_col].first().reset_index() #Para cada grupo de 'id', se selecciona el primer valor. Esto es porque cada 'id' tiene valores únicos para estas columnas.


movies = pd.merge(lang_genres, col_valor_unico, on='id', how='left')
#Se aplica merge para unir las columnas de valor único, con las de languages y genres. Esto devuelve un único DataFrame agrupado por id.

# %%
movies.head() #Se reducen las columnas considerablemente, y se han unificado correctamente los valores en género y lenguaje, que ahora son cadenas de texto.
# Out:
#        id spoken_languagesname               genresname  \
# 0     100              English            Crime, Comedy
# 1   10000              Español            Drama, Comedy
# 2   10001              English  Science Fiction, Comedy
# 3  100010              English               Drama, War
# 4  100017              Deutsch                    Drama
#
#                                  title     budget    revenue  \
# 0  Lock, Stock and Two Smoking Barrels  1350000.0  3897569.0
# 1            La estrategia del caracol        0.0        0.0
# 2                       Young Einstein        0.0        0.0
# 3                       Flight Command        0.0        0.0
# 4                              Hounded        0.0        0.0
#
#                                             overview release_date  \
# 0  A card sharp and his unwillingly-enlisted frie...   1998-03-05
# 1  A group of tenants living in an old house are ...   1993-12-25
# 2  Albert Einstein is the son of a Tasmanian appl...   1988-12-15
# 3  A rookie flyer, Ens. Alan Drake, joins the fam...   1940-12-27
# 4  Deals with the obsessive relationship between ...   2006-08-06
#
#    vote_average  vote_count popularity  runtime    status  \
# 0           7.5      1671.0    4.60786    105.0  Released
# 1           7.2         9.0   0.281609    116.0  Released
# 2           4.5        46.0   2.562888     91.0  Released
# 3           6.0         1.0   0.769266    116.0  Released
# 4           4.8         7.0   2.964103     87.0  Released
#
#                                              tagline  \
# 0                A Disgrace to Criminals Everywhere.
# 1                                               None
# 2                                              E=mc²
# 3  T-H-R-I-L-L AMERICA! Here come The Flying "HEL...
# 4                                               None
#
#                         production_companiesname  production_countriesname  \
# 0                            Handmade Films Ltd.            United Kingdom
# 1  Ministère de la Culture et de la Francophonie                  Colombia
# 2                                   Warner Bros.                 Australia
# 3                      Metro-Goldwyn-Mayer (MGM)  United States of America
# 4                       MMM Film Zimmermann & Co                   Germany
#
#    release_year    return
# 0          1998  2.887088
# 1          1993  0.000000
# 2          1988  0.000000
# 3          1940  0.000000
# 4          2006  0.000000

# %% [markdown]
# Con el nuevo DataFrame 'movies' corresponde ahora identificar y reemplazar valores nulos

# %%
#movies.isnull()
movies.isnull().sum()
# Out:
# id                              0
# spoken_languagesname            0
# genresname                      0
# title                           0
# budget                          0
# revenue                         0
# overview                      941
# release_date                    0
# vote_average                    0
# vote_count                      0
# popularity                      0
# runtime                       246
# status                         80
# tagline                     24959
# production_companiesname    11789
# production_countriesname     6208
# release_year                    0
# return                          0
# dtype: int64

# %%
#Crearemos una función para reemplazar valores nulos
def reemplazarNulos(df, columna, valor):
    """
    Esta función rellena los valores NaN en una columna específica de un DataFrame.
    Se esperan tres (3) parámentros:
    df (DataFrame): Sobre este DataFrame se realizará la operación.
    columna (str): Es el nombre de la columna del DataFrame en la que se reemplazarán los valores.
    valor: El valor con el que sr reemplazan los NaN en la columna.

    Se retorna un DataFrame con los nulos rellenados en las columnas indicadas.

    Si debo rellenar múltiples columnas con diferentes valores, se puede mapear un diccionario de claves-valor y aplicar la función de manera iterativa.
    """
    df[columna] = df[columna].fillna(valor)
    return df

# %%
mapeo_nulos = {
    'title': 'Sin Datos',
    'overview': 'Sin Datos',
    'release_date': '00/00/0000',
    'vote_average': 'Sin Datos',
    'vote_count': 'Sin Datos',
    'runtime': 'Sin Datos',
    'status': 'Sin Datos',
    'tagline': 'Sin Datos',
    'production_companiesname': 'Sin Datos',
    'production_countriesname': 'Sin Datos',
    'release_year': 0000
}
#Cuando no hay valores de fecha, se reemplazarán por 0.

for columna, dato in mapeo_nulos.items():
    movies = reemplazarNulos(movies, columna, dato) #Mediante un bucle for, aplico la función una única vez (para evitar utilizarla una vez por columna)

# %%
movies.isnull().sum() #Ya no tengo valores nulos
# Out:
# id                          0
# spoken_languagesname        0
# genresname                  0
# title                       0
# budget                      0
# revenue                     0
# overview                    0
# release_date                0
# vote_average                0
# vote_count                  0
# popularity                  0
# runtime                     0
# status                      0
# tagline                     0
# production_companiesname    0
# production_countriesname    0
# release_year                0
# return                      0
# dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45346 entries, 0 to 45345
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        45346 non-null  object
#  1   spoken_languagesname      45346 non-null  object
#  2   genresname                45346 non-null  object
#  3   title                     45346 non-null  object
#  4   budget                    45346 non-null  float64
#  5   revenue                   45346 non-null  float64
#  6   overview                  45346 non-null  object
#  7   release_date              45346 non-null  datetime64[ns]
#  8   vote_average              45346 non-null  float64
#  9   vote_count                45346 non-null  float64
#  10  popularity                45346 non-null  object
#  11  runtime                   45346 non-null  object
#  12  status                    45346 non-null  object
#  13  tagline                   45346 non-null  object
#  14  production_companiesname  45346 non-null  object
#  15  production_countriesname  45346 non-null  object
#  16  release_year              45346 non-null  int32
#  17  return                    45346 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int32(1), object(11)
# memory usage: 6.1+ MB

# %%
movies['id'] = movies['id'].astype('int64')
movies['popularity'] = movies['popularity'].astype('float64')

# %%
#movies['popularity'].info()
#movies['id'].info()
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45346 entries, 0 to 45345
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        45346 non-null  int64
#  1   spoken_languagesname      45346 non-null  object
#  2   genresname                45346 non-null  object
#  3   title                     45346 non-null  object
#  4   budget                    45346 non-null  float64
#  5   revenue                   45346 non-null  float64
#  6   overview                  45346 non-null  object
#  7   release_date              45346 non-null  datetime64[ns]
#  8   vote_average              45346 non-null  float64
#  9   vote_count                45346 non-null  float64
#  10  popularity                45346 non-null  float64
#  11  runtime                   45346 non-null  object
#  12  status                    45346 non-null  object
#  13  tagline                   45346 non-null  object
#  14  production_companiesname  45346 non-null  object
#  15  production_countriesname  45346 non-null  object
#  16  release_year              45346 non-null  int32
#  17  return                    45346 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int32(1), int64(1), object(9)
# memory usage: 6.1+ MB

# %%
movies.to_csv(r'C:\Users\GASTON\Desktop\PI1\movies_transformado.csv') #Extraemos un archivo CSV con las transformaciones realizadas

# %% [markdown]
# ## DATASET 'Credits'

# %%
df_credits = pd.read_csv(r'C:\Users\GASTON\Desktop\PI1\credits.csv', low_memory=False) #Creamos el DataFrame a partir del archivo CSV
df_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# CAST

# %%
#Vamos a desdoblar en dos DataFrame diferentes para poder trabajar de mejor manera, aunque se repita dos veces el proceso.
#DF1: una copia a partir de cast e id. DF2, a partir de crew e id.
cast = df_credits[['cast', 'id']].copy()
crew = df_credits[['crew', 'id']].copy()

# %%
cast.head()
# Out:
#                                                 cast     id
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...    862
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...   8844
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...  15602
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...  31357
# 4  [{'cast_id': 1, 'character': 'George Banks', '...  11862

# %%
crew.head()
# Out:
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
cast = desanidarColumnas(cast, ['cast'])
cast.head()
# Out:
#     id  castcast_id            castcharacter             castcredit_id  \
# 0  862         14.0            Woody (voice)  52fe4284c3a36847f8024f95
# 1  862         15.0   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 2  862         16.0  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 3  862         17.0       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 4  862         18.0              Rex (voice)  52fe4284c3a36847f8024fa5
#
#    castgender   castid       castname  castorder  \
# 0         2.0     31.0      Tom Hanks        0.0
# 1         2.0  12898.0      Tim Allen        1.0
# 2         2.0   7167.0    Don Rickles        2.0
# 3         2.0  12899.0     Jim Varney        3.0
# 4         2.0  12900.0  Wallace Shawn        4.0
#
#                    castprofile_path
# 0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg

# %% [markdown]
# CREW

# %%
crew = desanidarColumnas(crew, ['crew'])
crew.head()
# Out:
#     id             crewcredit_id crewdepartment  crewgender   crewid  \
# 0  862  52fe4284c3a36847f8024f49      Directing         2.0   7879.0
# 1  862  52fe4284c3a36847f8024f4f        Writing         2.0  12891.0
# 2  862  52fe4284c3a36847f8024f55        Writing         2.0      7.0
# 3  862  52fe4284c3a36847f8024f5b        Writing         2.0  12892.0
# 4  862  52fe4284c3a36847f8024f61        Writing         0.0  12893.0
#
#       crewjob        crewname                  crewprofile_path
# 0    Director   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
# 1  Screenplay     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# 2  Screenplay  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 3  Screenplay      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
# 4  Screenplay    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg

# %% [markdown]
# De cada DataFrame, se seleccionan las columnas que se necesitarán para el desarrollo de la API

# %%
actores = cast[['id','castname']].copy().rename(columns={'castname':'actor'}) 
#Creamos una copia sólo con las columnas ID y actor (renombrando la columna castname)
actores = actores.reset_index(drop=True)
actores.head(3)
# Out:
#     id        actor
# 0  862    Tom Hanks
# 1  862    Tim Allen
# 2  862  Don Rickles

# %%
crewjobs = crew['crewjob'].unique()
crewjobs #Se puede observar que tengo muchos trabajos diferentes, pero sólo necesito el de 'Director'
# Out:
# array(['Director', 'Screenplay', 'Producer', 'Executive Producer',
#        'Editor', 'Art Direction', 'Foley Editor', 'Animation',
#        'ADR Editor', 'Orchestrator', 'Color Timer', 'CG Painter',
#        'Original Story', 'Post Production Supervisor', 'Sculptor',
#        'Animation Director', 'Music', 'Layout', 'Music Editor',
#        'Negative Cutter', 'Title Designer',
#        'Supervising Technical Director', 'Songs', 'Supervising Animator',
#        'Sound Designer', 'Production Supervisor',
#        'Executive Music Producer', 'Visual Effects Supervisor',
#        'Visual Effects', 'Lighting Supervisor', 'Character Designer',
#        'Set Dresser', 'Editorial Manager', 'Assistant Editor',
#        'Editorial Coordinator', 'Production Coordinator',
#        'Unit Publicist', 'Sound Re-Recording Mixer',
#        'Supervising Sound Editor', 'Sound Effects Editor',
#        'Sound Design Assistant', 'Assistant Sound Editor',
#        'Casting Consultant', 'ADR Voice Casting',
#        'Original Music Composer', 'Casting', 'Animation Supervisor',
#        'Production Design', 'Director of Photography', 'Novel',
#        'Characters', 'Writer', 'Sound Recordist', 'Costume Design',
#        'Special Effects Coordinator', 'Special Effects',
#        'Stunt Coordinator', 'Stunts', 'Set Decoration',
#        'Costume Supervisor', 'Script Supervisor',
#        'Art Department Coordinator', 'Assistant Art Director',
#        'Construction Coordinator', 'Assistant Costume Designer',
#        'Hairstylist', 'Key Hair Stylist', 'Makeup Artist',
#        'Dialogue Editor', 'Camera Operator', 'Steadicam Operator',
#        'Still Photographer', 'First Assistant Camera', 'Rigging Gaffer',
#        'Music Supervisor', 'First Assistant Editor',
#        'Technical Supervisor', 'Associate Producer',
#        'Unit Production Manager', 'Assistant Director',
#        'Casting Associate', 'Set Costumer', 'Digital Effects Supervisor',
#        'Additional Soundtrack', 'Co-Costume Designer', 'Sound mixer',
#        'Supervising Sound Effects Editor', 'Boom Operator',
#        'Production Manager', 'Casting Assistant', 'Location Manager',
#        'Story', 'Supervising Art Director', 'Armorer', 'Gaffer',
#        'Special Effects Supervisor', 'Visual Effects Coordinator',
#        'Visual Effects Editor', 'Background Designer',
#        'Animation Manager', 'Co-Producer', 'Foley',
#        'Construction Foreman', 'Lead Painter', 'Painter',
#        'Standby Painter', 'Key Grip', 'Grip', 'Carpenter',
#        'Choreographer', 'Craft Service', 'Driver',
#        'Post Production Assistant', 'Property Master', 'Security',
#        'Set Medic', 'Set Production Assistant', 'Stand In',
#        'Transportation Captain', 'Transportation Coordinator',
#        'First Assistant Director', 'Best Boy Electric', 'Electrician',
#        'Production Accountant', 'First Assistant Sound Editor',
#        'Production Sound Mixer', 'Sound Editor', 'Special Sound Effects',
#        'Studio Teachers', 'Creative Consultant', 'Dolby Consultant',
#        'Makeup Department Head', 'Author', 'Set Designer', 'Leadman',
#        'Greensman', 'Helicopter Camera', 'Additional Camera',
#        'Lighting Technician', 'Dialect Coach',
#        'Production Office Assistant', 'Line Producer', 'Adaptation',
#        'Script Editor', 'Visual Effects Designer', 'Makeup Designer',
#        'Underwater Camera', 'Hair Designer', 'Propmaker',
#        'Digital Compositors', 'Rigging Grip', 'Loader',
#        'Video Assist Operator', 'Post-Production Manager',
#        'Public Relations', 'Legal Services', 'Location Scout',
#        'Production Illustrator', 'Scenic Artist',
#        'Chief Lighting Technician', 'Assistant Property Master',
#        'Dolly Grip', 'Wardrobe Supervisor', 'Animal Coordinator',
#        'Pyrotechnician', 'Assistant Production Manager', 'Local Casting',
#        'Apprentice Sound Editor', 'Musician', 'Second Assistant Director',
#        'Key Makeup Artist', 'ADR & Dubbing', 'Seamstress', 'Thanks',
#        'Sound Mixer', 'Set Dressing Artist', 'Storyboard',
#        'Additional Music', 'Chef', 'Mixing Engineer', 'Production Intern',
#        'Telecine Colorist', 'Set Dressing Production Assistant',
#        'Finance', 'Theatre Play', 'Creator', 'Additional Editing',
#        'Co-Executive Producer', 'Executive In Charge Of Post Production',
#        'Additional Photography', 'Executive In Charge Of Production',
#        'Makeup Effects', 'Color Designer', 'Transportation Co-Captain',
#        'Supervising ADR Editor', 'Supervising Music Editor',
#        'Makeup Effects Designer', 'Tattooist', 'Camera Intern',
#        'CGI Supervisor', 'Scoring Mixer', 'Visual Effects Producer',
#        'Cableman', 'Sound Engineer', 'Other', "Actor's Assistant",
#        'Publicist', 'Production Controller', 'Cinematography',
#        'Compositors', 'Sound', 'Prosthetic Supervisor',
#        'Supervising Film Editor', 'Visual Effects Design Consultant',
#        'Title Graphics', 'Scenario Writer', 'Conductor', 'Pilot',
#        'Second Unit Cinematographer', 'Systems Administrators & Support',
#        'Art Department Assistant', 'Camera Technician', 'Machinist',
#        'Underwater Director of Photography', 'CG Supervisor',
#        'Second Unit', 'Utility Stunts', 'Creature Design', 'Modeling',
#        'Visual Effects Art Director', nan, 'Hair Department Head',
#        'Co-Art Director', 'Aerial Camera', '3D Artist', 'Unit Manager',
#        'Short Story', 'Additional Writing', 'Additional Dialogue',
#        'Settings', 'Wigmaker', 'Editorial Staff', 'Camera Supervisor',
#        'Key Animation', 'Picture Car Coordinator',
#        'Production Office Coordinator', 'Projection', 'ADR Supervisor',
#        'Aerial Coordinator', 'Sound Director', 'Vocal Coach',
#        'Conceptual Design', 'Camera Department Manager', 'Screenstory',
#        'I/O Manager', 'Stunts Coordinator', 'Book', 'Camera Loader',
#        'Software Engineer', 'I/O Supervisor', 'Makeup Supervisor',
#        'Assistant Production Coordinator', 'CG Animator',
#        'Mechanical Designer', '3D Animator', 'Editorial Services',
#        'Music Director', 'Art Department Manager',
#        'Post Production Consulting', 'Visual Development',
#        'Animation Production Assistant', 'Sequence Supervisor',
#        'Character Technical Supervisor', 'Editorial Production Assistant',
#        'Associate Editor', 'Animal Wrangler', 'Dialogue', 'Idea',
#        'Prosthetic Makeup Artist', '3D Modeller', 'VFX Artist',
#        'Lead Animator', '3D Coordinator', 'Digital Producer',
#        'Martial Arts Choreographer', 'Aerial Director of Photography',
#        'CGI Director', 'Presenter', 'Administration', 'Music Programmer',
#        'Comic Book', 'Recording Supervision', 'Hair Supervisor',
#        'Stunt Double', 'Script', 'Musical', 'Interior Designer',
#        'Researcher', 'Special Guest Director', 'Continuity',
#        'Mix Technician', 'Sound Montage Associate',
#        'Motion Capture Artist', 'Mechanical & Creature Designer',
#        'Hair Setup', 'Sound Effects', 'Commissioning Editor',
#        'Conceptual Illustrator', 'Script Coordinator',
#        'Executive Consultant', 'Animatronic and Prosthetic Effects',
#        'Second Unit Director of Photography', 'Third Assistant Director',
#        'Key Costumer', 'Marine Coordinator', 'Lighting Director',
#        'Translator', '24 Frame Playback', 'Production Artist',
#        'Set Decoration Buyer', 'Temp Music Editor',
#        'Animatronics Designer', '3D Supervisor', 'Key Set Costumer',
#        'Animation Department Coordinator', 'Sound Effects Designer',
#        'Pyrotechnic Supervisor', 'Teleplay',
#        'Supervising Dialogue Editor', 'Roto Supervisor',
#        'Lighting Camera', 'Tailor', 'Digital Effects Producer',
#        'Lighting Artist', 'Executive Visual Effects Producer',
#        'Ager/Dyer', 'Utility Sound', 'Score Engineer',
#        'Associate Choreographer', 'VFX Supervisor',
#        'Assistant Set Dresser', 'Draughtsman', 'Costume Coordinator',
#        'Aerial Camera (suggest in addition to Helicopter Camera)',
#        'Tattoo Designer', 'Additional Sound Re-Recording Mixer',
#        'Co-Director', 'Chief Technician / Stop-Motion Expert',
#        'Costume Illustrator', 'Supervising Producer',
#        'Digital Intermediate', 'Steadycam', 'Sets & Props Artist',
#        'Prop Maker', 'Poem', 'Second Film Editor',
#        'Additional Editorial Assistant', 'Software Team Lead',
#        'Lighting Production Assistant', 'VFX Production Coordinator',
#        'Sign Painter', 'Shading', 'Set Dressing Supervisor',
#        'Fix Animator', 'In Memory Of', 'Best Boy Electrician',
#        'Sequence Leads', 'Co-Editor', 'Lead Set Dresser',
#        'Storyboard Designer', 'Documentation & Support',
#        'VFX Director of Photography', 'Fight Choreographer',
#        'Set Decorating Coordinator', 'Techno Crane Operator',
#        'Script Researcher', 'Imaging Science', 'Aerial Camera Technician',
#        'Matchmove Supervisor', 'Set Dressing Manager',
#        'Animatronics Supervisor', 'Wig Designer', '2D Supervisor',
#        'Animation Fix Coordinator', 'Lighting Manager',
#        'Directing Lighting Artist', 'Master Lighting Artist',
#        'Photoscience Manager', 'Department Administrator',
#        'Information Systems Manager', 'Simulation & Effects Artist',
#        'Armory Coordinator', 'Story Editor', '2D Artist', 'Gun Wrangler',
#        'Consulting Producer', 'Additional Still Photographer',
#        'Visual Effects Technical Director', 'Music Score Producer',
#        'Radio Play', 'Pre-Visualization Supervisor', 'Underwater Gaffer',
#        'Executive in Charge of Finance', 'Production Director',
#        'Theme Song Performance', 'VFX Editor', 'Development Manager',
#        'Manager of Operations', 'Opera', 'Quality Control Supervisor',
#        'Rigging Supervisor', 'Playback Singer',
#        'Creature Technical Director', 'Co-Writer',
#        'Supervisor of Production Resources', 'Assistant Music Supervisor',
#        'Creative Producer', 'Series Writer', 'Schedule Coordinator',
#        'Temp Sound Editor', 'Comic-Zeichner', 'Lead Character Designer',
#        'Voice', 'Archival Footage Coordinator',
#        'Archival Footage Research', 'Set Production Intern',
#        'Additional Music Supervisor', 'treatment',
#        'Graphic Novel Illustrator', 'Motion Actor',
#        'Battle Motion Coordinator', 'Sets & Props Supervisor',
#        'Cloth Setup', 'Facial Setup Artist', 'Sequence Artist',
#        'CG Engineer', 'Prop Designer', 'Shoe Design',
#        'Simulation & Effects Production Assistant', 'Video Game',
#        'Opening/Ending Animation', 'Epk Camera Operator',
#        'Script Consultant', 'Coordinating Producer',
#        'Lighting Coordinator', 'Dramaturgy', 'Prosthetic Designer',
#        'Drone Operator', '3D Generalist', 'Russian Arm Operator',
#        'Ultimate Arm Operator', '3D Director', 'Dramaturgie', 'Actor',
#        'Costume Consultant', 'Character Modelling Supervisor',
#        'Stereoscopic Coordinator'], dtype=object)

# %%
directores = crew[crew['crewjob'] == 'Director'] #Se aplica una máscara para sólo obtener los valores en los que el crewjob sea 'Director'

directores = directores[['id', 'crewname']].copy().rename(columns={'crewname': 'director'})
# Filtramos las columnas de id (la usaremos para unir los DataFrame) y crewname, que se renombra a 'director'.
directores = directores.reset_index(drop=True)
directores.head(3)
# Out:
#       id       director
# 0    862  John Lasseter
# 1   8844   Joe Johnston
# 2  15602  Howard Deutch

# %%
crew[(crew['id'] == 5) & (crew['crewjob'] == 'Director')] #Esta es una verificación para confirmar películas con múltiples directores
# Out:
#      id             crewcredit_id crewdepartment  crewgender  crewid  \
# 400   5  52fe420dc3a36847f800012d      Directing         1.0  3110.0
# 401   5  52fe420dc3a36847f8000133      Directing         2.0  3111.0
# 402   5  52fe420dc3a36847f8000139      Directing         2.0  2294.0
# 403   5  52fe420dc3a36847f800013f      Directing         2.0   138.0
#
#       crewjob            crewname                  crewprofile_path
# 400  Director      Allison Anders  /rsfxpcNEdmNqZyNcct0J695LhBK.jpg
# 401  Director  Alexandre Rockwell                              None
# 402  Director    Robert Rodriguez  /bPqRdLWWwpOT8sBdj9PWOzNgwou.jpg
# 403  Director   Quentin Tarantino  /9ci4NBvHXJktxjALdJsrtasqgtV.jpg

# %%
directores_actores = pd.merge(directores, actores, on='id', how='left')
#Se utiliza merge para unir por 'id' a los directores y actores
directores_actores.head()
# Out:
#     id       director          actor
# 0  862  John Lasseter      Tom Hanks
# 1  862  John Lasseter      Tim Allen
# 2  862  John Lasseter    Don Rickles
# 3  862  John Lasseter     Jim Varney
# 4  862  John Lasseter  Wallace Shawn

# %%
directores_actores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615750 entries, 0 to 615749
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        615750 non-null  int64
#  1   director  615750 non-null  object
#  2   actor     613363 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 14.1+ MB

# %%
directores_actores['actor'] = directores_actores['actor'].astype(str)
directores_actores['director'] = directores_actores['director'].astype(str)
#Aquí simplemente se convierten las columnas en cadenas de texto

# %%
creditos = directores_actores.groupby('id').agg({
    'director': lambda x: ', '.join(set(x)) if len(set(x)) > 1 else x.iloc[0], #Aquí se verificará si hay más de un director después de convertirse en set (eliminándose duplicados). Si hay más de 1, se concatenan separados por comas. Si sólo hay uno, se agrega el primer valor.
    'actor': lambda x: ', '.join(x) #En este caso, siempre se concatenan los elementos.
}).reset_index() #Se concatenan por 'id' de película a los directores y actores
creditos.head()
# Out:
#    id                                           director  \
# 0   2                                     Aki Kaurismäki
# 1   3                                     Aki Kaurismäki
# 2   5  Robert Rodriguez, Alexandre Rockwell, Allison ...
# 3   6                                    Stephen Hopkins
# 4  11                                       George Lucas
#
#                                                actor
# 0  Turo Pajala, Susanna Haavisto, Matti Pellonpää...
# 1  Matti Pellonpää, Kati Outinen, Sakari Kuosmane...
# 2  Tim Roth, Antonio Banderas, Jennifer Beals, Ma...
# 3  Emilio Estevez, Cuba Gooding Jr., Denis Leary,...
# 4  Mark Hamill, Harrison Ford, Carrie Fisher, Pet...

# %%
creditos.duplicated().sum() #Verificamos que no hayan duplicados
# Out:
# 0

# %%
#Guardamos el DataFrame como CSV 
creditos.to_csv(r'C:\Users\GASTON\Desktop\PI1\credits_transformado.csv', index=False)

# %% [markdown]
# ## UNIFICACION DE DATASETS

# %% [markdown]
# Para el desarrollo de la API, es preciso tener un Dataset unificado del que pueda obtener los diferentes valores para realizar consultas

# %%
#Se unifican los datasets a través de la columna 'id' 
movies_credits = pd.merge(movies, creditos, on='id', how='left')
movies_credits.head()
# Out:
#        id spoken_languagesname               genresname  \
# 0     100              English            Crime, Comedy
# 1   10000              Español            Drama, Comedy
# 2   10001              English  Science Fiction, Comedy
# 3  100010              English               Drama, War
# 4  100017              Deutsch                    Drama
#
#                                  title     budget    revenue  \
# 0  Lock, Stock and Two Smoking Barrels  1350000.0  3897569.0
# 1            La estrategia del caracol        0.0        0.0
# 2                       Young Einstein        0.0        0.0
# 3                       Flight Command        0.0        0.0
# 4                              Hounded        0.0        0.0
#
#                                             overview release_date  \
# 0  A card sharp and his unwillingly-enlisted frie...   1998-03-05
# 1  A group of tenants living in an old house are ...   1993-12-25
# 2  Albert Einstein is the son of a Tasmanian appl...   1988-12-15
# 3  A rookie flyer, Ens. Alan Drake, joins the fam...   1940-12-27
# 4  Deals with the obsessive relationship between ...   2006-08-06
#
#    vote_average  vote_count  popularity runtime    status  \
# 0           7.5      1671.0    4.607860   105.0  Released
# 1           7.2         9.0    0.281609   116.0  Released
# 2           4.5        46.0    2.562888    91.0  Released
# 3           6.0         1.0    0.769266   116.0  Released
# 4           4.8         7.0    2.964103    87.0  Released
#
#                                              tagline  \
# 0                A Disgrace to Criminals Everywhere.
# 1                                          Sin Datos
# 2                                              E=mc²
# 3  T-H-R-I-L-L AMERICA! Here come The Flying "HEL...
# 4                                          Sin Datos
#
#                         production_companiesname  production_countriesname  \
# 0                            Handmade Films Ltd.            United Kingdom
# 1  Ministère de la Culture et de la Francophonie                  Colombia
# 2                                   Warner Bros.                 Australia
# 3                      Metro-Goldwyn-Mayer (MGM)  United States of America
# 4                       MMM Film Zimmermann & Co                   Germany
#
#    release_year    return            director  \
# 0          1998  2.887088         Guy Ritchie
# 1          1993  0.000000      Sergio Cabrera
# 2          1988  0.000000       Yahoo Serious
# 3          1940  0.000000       Frank Borzage
# 4          2006  0.000000  Angelina Maccarone
#
#                                                actor
# 0  Jason Flemyng, Dexter Fletcher, Nick Moran, Ja...
# 1                                                nan
# 2  Yahoo Serious, Odile Le Clezio, Peewee Wilson,...
# 3  Robert Taylor, Ruth Hussey, Walter Pidgeon, Pa...
# 4  Kostja Ullmann, Maren Kroymann, Moritz Grove, ...

# %%
#df_peliculas = pd.read_csv(r'C:\Users\GASTON\Desktop\PI1\movies_transformado.csv', low_memory=False)
#df_creditos = pd.read_csv(r'C:\Users\GASTON\Desktop\PI1\credits_transformado.csv', low_memory=False)
#movies_credits = pd.merge(df_peliculas, df_creditos, on='id', how='left')
#Si tengo los datasets con las transformaciones, puedo correr el código desde aquí para unificarlos.

# %%
#Guardamos el DataFrame unificado y transformado como CSV 
movies_credits.to_csv(r'C:\Users\GASTON\Desktop\PI1\movies_credits.csv', index=False)
